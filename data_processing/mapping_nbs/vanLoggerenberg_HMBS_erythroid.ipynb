# %%
import pandas as pd
import joblib
from data_processing.main import read_scoreset
from tqdm import tqdm
from pathlib import Path
from data_processing.mapping_nbs import mapping_utils
from data_processing.mapping_nbs import plotting
pd.set_option('display.max_columns', 500)

dataset_name = "vanLoggerenberg_HMBS_erythroid"
dataset_path = Path("/data/dzeiberg/mave_calibration/data/") / dataset_name
assert dataset_path.exists()

# %%
metadata, gene_info, gnomAD_df, spliceAI_df, clinvar_df = mapping_utils.load_mapping_data()

# %%
scoreset = read_scoreset(dataset_path / "scoreset.csv")

# %%
scoreset
# Out:
#                          accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0        urn:mavedb:00000108-a-2#1      NaN          NaN   p.Val94Tyr
# 1        urn:mavedb:00000108-a-2#2      NaN          NaN   p.Val94Trp
# 2        urn:mavedb:00000108-a-2#3      NaN          NaN   p.Val94Thr
# 3        urn:mavedb:00000108-a-2#4      NaN          NaN   p.Val94Ter
# 4        urn:mavedb:00000108-a-2#5      NaN          NaN   p.Val94Ser
# ...                            ...      ...          ...          ...
# 6481  urn:mavedb:00000108-a-2#6482      NaN          NaN  p.Ala112Cys
# 6482  urn:mavedb:00000108-a-2#6483      NaN          NaN  p.Ala112Asp
# 6483  urn:mavedb:00000108-a-2#6484      NaN          NaN  p.Ala112Asn
# 6484  urn:mavedb:00000108-a-2#6485      NaN          NaN  p.Ala112Arg
# 6485  urn:mavedb:00000108-a-2#6486      NaN          NaN    p.Ala112=
#
#          score        sd  df        se author_transcript  synonymous  nonsense
# 0     0.011268  0.400078   2  0.282898       NM_000190.4       False     False
# 1    -0.601767  0.199376   2  0.140980       NM_000190.4       False     False
# 2     0.488784  0.473580   4  0.236790       NM_000190.4       False     False
# 3     0.438297  0.256071   2  0.181069       NM_000190.4       False      True
# 4    -0.243077  0.367972   6  0.150224       NM_000190.4       False     False
# ...        ...       ...  ..       ...               ...         ...       ...
# 6481  1.113248  0.151411   2  0.107064       NM_000190.4       False     False
# 6482  0.163642  0.201522   4  0.100761       NM_000190.4       False     False
# 6483 -0.701918  0.757431   2  0.535584       NM_000190.4       False     False
# 6484 -0.534498  0.605914   4  0.302957       NM_000190.4       False     False
# 6485  1.029030  0.085064   4  0.042532       NM_000190.4        True     False
#
# [6486 rows x 11 columns]

# %%
if "author_transcript" not in scoreset.columns or scoreset.author_transcript.isna().all():
    AUTHOR_TRANSCRIPT = gene_info.loc[metadata.loc[dataset_name],'MANE_RefSeq_nuc'].values[0].split(".")[0]
else:
    AUTHOR_TRANSCRIPT = scoreset.author_transcript.iloc[0].split(".")[0]

# %%
AUTHOR_TRANSCRIPT
# Out:
# 'NM_000190'

# %% [markdown]
# # Add ClinVar annotations

# %%
clinvar_hgvs_pro_summaries = mapping_utils.get_clinvar_summaries(clinvar_df,AUTHOR_TRANSCRIPT)
# Out:
# 100%|██████████| 311/311 [00:00<00:00, 2094.12it/s]

# %%
scoreset_w_clinvar = pd.merge(scoreset.set_index("hgvs_pro"),clinvar_hgvs_pro_summaries,
                            left_index=True,
                            right_index=True,
                            how="left",
                            validate="one_to_one",
                            suffixes=("","_clinvar"))

# %% [markdown]
# # Add gnomAD annotations

# %%
Ensembl_transcript_stable_ids = mapping_utils.translate_refseq_to_ensembl(AUTHOR_TRANSCRIPT)

# %%
Ensembl_transcript_stable_ids
# Out:
# array(['ENST00000652429'], dtype=object)

# %%
gnomAD_info = mapping_utils.gather_gnomAD_info(gnomAD_df,Ensembl_transcript_stable_ids,[AUTHOR_TRANSCRIPT,])

# %%
scoreset_processed = pd.merge(scoreset_w_clinvar,gnomAD_info,
                                        left_index=True,right_index=True,how="left",validate="one_to_one").reset_index()

# %%
scoreset_processed
# Out:
#          hgvs_pro                     accession  hgvs_nt  hgvs_splice  \
# 0      p.Val94Tyr     urn:mavedb:00000108-a-2#1      NaN          NaN
# 1      p.Val94Trp     urn:mavedb:00000108-a-2#2      NaN          NaN
# 2      p.Val94Thr     urn:mavedb:00000108-a-2#3      NaN          NaN
# 3      p.Val94Ter     urn:mavedb:00000108-a-2#4      NaN          NaN
# 4      p.Val94Ser     urn:mavedb:00000108-a-2#5      NaN          NaN
# ...           ...                           ...      ...          ...
# 6481  p.Ala112Cys  urn:mavedb:00000108-a-2#6482      NaN          NaN
# 6482  p.Ala112Asp  urn:mavedb:00000108-a-2#6483      NaN          NaN
# 6483  p.Ala112Asn  urn:mavedb:00000108-a-2#6484      NaN          NaN
# 6484  p.Ala112Arg  urn:mavedb:00000108-a-2#6485      NaN          NaN
# 6485    p.Ala112=  urn:mavedb:00000108-a-2#6486      NaN          NaN
#
#          score        sd  df        se author_transcript  synonymous  \
# 0     0.011268  0.400078   2  0.282898       NM_000190.4       False
# 1    -0.601767  0.199376   2  0.140980       NM_000190.4       False
# 2     0.488784  0.473580   4  0.236790       NM_000190.4       False
# 3     0.438297  0.256071   2  0.181069       NM_000190.4       False
# 4    -0.243077  0.367972   6  0.150224       NM_000190.4       False
# ...        ...       ...  ..       ...               ...         ...
# 6481  1.113248  0.151411   2  0.107064       NM_000190.4       False
# 6482  0.163642  0.201522   4  0.100761       NM_000190.4       False
# 6483 -0.701918  0.757431   2  0.535584       NM_000190.4       False
# 6484 -0.534498  0.605914   4  0.302957       NM_000190.4       False
# 6485  1.029030  0.085064   4  0.042532       NM_000190.4        True
#
#       nonsense  num_p_lp  num_b_lb  num_conflicting  num_VUS clinvar_names  \
# 0        False       NaN       NaN              NaN      NaN           NaN
# 1        False       NaN       NaN              NaN      NaN           NaN
# 2        False       NaN       NaN              NaN      NaN           NaN
# 3         True       NaN       NaN              NaN      NaN           NaN
# 4        False       NaN       NaN              NaN      NaN           NaN
# ...        ...       ...       ...              ...      ...           ...
# 6481     False       NaN       NaN              NaN      NaN           NaN
# 6482     False       NaN       NaN              NaN      NaN           NaN
# 6483     False       NaN       NaN              NaN      NaN           NaN
# 6484     False       NaN       NaN              NaN      NaN           NaN
# 6485     False       NaN       NaN              NaN      NaN           NaN
#
#       clinvar_records  clinvar_spliceAI_max  gnomAD_variants_maxAC_AF  \
# 0                 NaN                   NaN                       NaN
# 1                 NaN                   NaN                       NaN
# 2                 NaN                   NaN                       NaN
# 3                 NaN                   NaN                       NaN
# 4                 NaN                   NaN                       NaN
# ...               ...                   ...                       ...
# 6481              NaN                   NaN                       NaN
# 6482              NaN                   NaN              6.849860e-07
# 6483              NaN                   NaN                       NaN
# 6484              NaN                   NaN                       NaN
# 6485              NaN                   NaN                       NaN
#
#       gnomAD_variants_max_spliceAI_score           gnomAD_variants_VCF_INFO
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 6481                                 NaN                                NaN
# 6482                                0.03  11:119089751:C:A|11:119089751:C:A
# 6483                                 NaN                                NaN
# 6484                                 NaN                                NaN
# 6485                                 NaN                                NaN
#
# [6486 rows x 21 columns]

# %%
scoreset_processed.to_csv(dataset_path / "scoreset_processed.csv",index=False)

# %% [markdown]
# # Reload Processed

# %%
scoreset_processed = pd.read_csv(dataset_path / "scoreset_processed.csv")

# %%
def conflicting_interpretations(r):
    """
    Check if a record has conflicting interpretations
    P/LP and B/LB ; P/LP and VUS ; B/LB and VUS ; P/LP and conflicting ; B/LB and conflicting
    If data is mapped at the protein level, this could be a result of different RNA substitutions
    If data is mapped at the RNA level, this is a true conflict

    Parameters
    ----------
    r : pd.Series
        A record from the ClinVar data frame

    Returns
    -------
    bool
        True if there are conflicting interpretations, False otherwise
    """
    return r.num_p_lp > 0 and r.num_b_lb > 0 or \
            r.num_p_lp > 0 and r.num_VUS > 0 or \
            r.num_b_lb > 0 and r.num_VUS > 0 or \
            r.num_p_lp > 0 and r.num_conflicting > 0 or \
            r.num_b_lb > 0 and r.num_conflicting > 0


def is_pathogenic(r):
    return r.num_p_lp > 0 and not conflicting_interpretations(r) and r.clinvar_spliceAI_max <= .5

def is_benign(r):
    return r.num_b_lb > 0 and not conflicting_interpretations(r) and r.clinvar_spliceAI_max <= .5

def is_vus(r):
    return r.num_VUS > 0

def is_conflicting(r):
    return r.num_conflicting > 0

def is_gnomAD(r):
    return r.gnomAD_variants_maxAC_AF > 0 and r.gnomAD_variants_max_spliceAI_score <= .5

def is_synonymous(r):
    return r.synonymous and r.num_p_lp == 0 and r.clinvar_spliceAI_max <= .5

# %%
sample_data = {
    "P/LP" : scoreset_processed[scoreset_processed.apply(lambda r: not r.nonsense and is_pathogenic(r),axis=1)],
    "B/LB" : scoreset_processed[scoreset_processed.apply(lambda r: not r.nonsense and is_benign(r),axis=1)],
    'gnomAD': scoreset_processed[scoreset_processed.apply(lambda r: not r.nonsense and is_gnomAD(r),axis=1)],
    'synonymous' : scoreset_processed[scoreset_processed.apply(is_synonymous,axis=1)],
}
sample_data = {k : v for k,v in sample_data.items() if len(v)}

INVERT_SCORES = False
if INVERT_SCORES:
    for k in sample_data:
        sample_data[k] = sample_data[k].assign(score= -sample_data[k].score)

# %%
for sample_name, sample in sample_data.items():
    print(f"{sample_name}: {sample.shape[0]}")
# Out:
# P/LP: 36
# B/LB: 61
# gnomAD: 357
# synonymous: 66

# %%
plotting.plot_samples({k : v.score.values for k,v in sample_data.items()})
# Out:
# (<Figure size 1200x1200 with 4 Axes>,
#  array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>], dtype=object))

# %%
if 'synonymous' in sample_data:
    pd.DataFrame.from_records([*[dict(sample_name='P/LP',score=score) for score in sample_data['P/LP'].score.values],
                                *[dict(sample_name='B/LB',score=score) for score in sample_data['B/LB'].score.values],
                                *[dict(sample_name='gnomAD',score=score) for score in sample_data['gnomAD'].score.values],
                                *[dict(sample_name='synonymous',score=score) for score in sample_data['synonymous'].score.values]]).to_csv(dataset_path / "samples.csv",index=False)
else:
    pd.DataFrame.from_records([*[dict(sample_name='P/LP',score=score) for score in sample_data['P/LP'].score.values],
                            *[dict(sample_name='B/LB',score=score) for score in sample_data['B/LB'].score.values],
                            *[dict(sample_name='gnomAD',score=score) for score in sample_data['gnomAD'].score.values]]).to_csv(dataset_path / "samples.csv",index=False)

# %%
old = joblib.load(dataset_path / "hgvs_pro.pkl")

# %%
clinvar_hgvs_pro_summaries[clinvar_hgvs_pro_summaries.index.isin(set(old['p_lp'].values) - set(sample_data['P/LP'].hgvs_pro.values))]
# Out:
#              num_p_lp  num_b_lb  num_conflicting  num_VUS  \
# hgvs_pro
# p.Arg167Gln         1         0                0        0
# p.Gln204His         1         0                0        0
# p.Gly236Ser         1         0                0        0
#
#                                         clinvar_names  clinvar_records  \
# hgvs_pro
# p.Arg167Gln  NM_000190.4(HMBS):c.500G>A (p.Arg167Gln)                1
# p.Gln204His  NM_000190.4(HMBS):c.612G>T (p.Gln204His)                1
# p.Gly236Ser  NM_000190.4(HMBS):c.706G>A (p.Gly236Ser)                1
#
#              clinvar_spliceAI_max
# hgvs_pro
# p.Arg167Gln                  0.80
# p.Gln204His                  0.96
# p.Gly236Ser                  0.68

# %%
clinvar_hgvs_pro_summaries[clinvar_hgvs_pro_summaries.index.isin(set(old['b_lb'].values) - set(sample_data['B/LB'].hgvs_pro.values))]
# Out:
#            num_p_lp  num_b_lb  num_conflicting  num_VUS  \
# hgvs_pro
# p.Pro241=         0         1                1        0
# p.Thr35=          0         1                0        1
# p.Val90=          0         1                0        0
#
#                                                clinvar_names  clinvar_records  \
# hgvs_pro
# p.Pro241=  NM_000190.4(HMBS):c.723C>T (p.Pro241=)|NM_0001...                2
# p.Thr35=   NM_000190.4(HMBS):c.105G>C (p.Thr35=)|NM_00019...                2
# p.Val90=               NM_000190.4(HMBS):c.270G>A (p.Val90=)                1
#
#            clinvar_spliceAI_max
# hgvs_pro
# p.Pro241=                  0.05
# p.Thr35=                   0.19
# p.Val90=                   0.71

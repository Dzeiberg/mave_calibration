# %%
from pathlib import Path
import pandas as pd
import json
import mavehgvs
dataset_path = Path("/mnt/i/bio/mave_curation/Giacomelli_p53_nullEtoposide/")

# %%
data = pd.read_csv(dataset_path / "raw" / "urn_mavedb_00000068-c-1_scores.csv")

# %%
data = data.dropna(subset=["hgvs_pro",'score'])

# %%
data
# Out:
#                          accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0        urn:mavedb:00000068-c-1#1      NaN          NaN  p.Lys381Trp
# 1        urn:mavedb:00000068-c-1#2      NaN          NaN  p.Lys381Val
# 2        urn:mavedb:00000068-c-1#3      NaN          NaN  p.Lys381Thr
# 3        urn:mavedb:00000068-c-1#4      NaN          NaN  p.Lys381Ser
# 4        urn:mavedb:00000068-c-1#5      NaN          NaN  p.Lys381Arg
# ...                            ...      ...          ...          ...
# 8269  urn:mavedb:00000068-c-1#8270      NaN          NaN      p.Pro4=
# 8270  urn:mavedb:00000068-c-1#8271      NaN          NaN    p.Pro4Ala
# 8271  urn:mavedb:00000068-c-1#8272      NaN          NaN    p.Glu3Ter
# 8272  urn:mavedb:00000068-c-1#8273      NaN          NaN    p.Glu3Tyr
# 8273  urn:mavedb:00000068-c-1#8274      NaN          NaN    p.Glu3Trp
#
#          score
# 0     0.689738
# 1     0.921703
# 2     1.100509
# 3     1.262013
# 4     0.922170
# ...        ...
# 8269  0.280442
# 8270 -1.175946
# 8271 -2.021259
# 8272  0.300898
# 8273  0.082104
#
# [8258 rows x 5 columns]

# %%
data.to_csv(dataset_path / 'scoreset.csv', index=False)

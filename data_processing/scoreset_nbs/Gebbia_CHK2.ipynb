# %%
import pandas as pd
from pathlib import Path
import json
dataset_path = Path("/data/dzeiberg/mave_calibration/data/Gebbia_CHK2/")
assert dataset_path.exists()

# %%
data = pd.read_csv(dataset_path / 'raw' / 'media-1.csv')
data = data.assign(hgvs_pro=data.hgvs_pro.str.replace("*",'Ter'))
data = data.rename(columns=dict(score='raw_score',
                                error='raw_score_error'))
data = data.rename(columns=dict(refined_score='score',
                                refined_score_se='score_se'))

# %%
data
# Out:
#       aaChange     hgvs_pro        type  raw_score  raw_score_error  score  \
# 0          S2S      p.Ser2=  synonymous       1.09             0.84   1.09
# 1          S2A    p.Ser2Ala    missense       1.11             0.05   1.12
# 2          S2V    p.Ser2Val    missense       1.32             0.05   1.02
# 3          S2R    p.Ser2Arg    missense       1.31             0.10   1.31
# 4          S2D    p.Ser2Asp    missense       1.31             0.04   1.31
# ...        ...          ...         ...        ...              ...    ...
# 11377    L543M  p.Leu543Met    missense       1.37             0.15   0.87
# 11378    L543W  p.Leu543Trp    missense        NaN              NaN    NaN
# 11379    L543H  p.Leu543His    missense       1.35             1.90   1.46
# 11380    L543Q  p.Leu543Gln    missense        NaN              NaN   1.22
# 11381    L543*  p.Leu543Ter    nonsense       1.15             0.57   1.15
#
#        score_se   LLR       LLR_strength
# ...

# %%
data.to_csv(dataset_path / 'scoreset.csv',index=False)

# %%
metadata = dict(uniprot_acc='O96017')
with open(dataset_path / 'metadata.json', 'w') as f:
    json.dump(metadata, f)

# %%
from pathlib import Path
import pandas as pd
import os
import json
dataset_path = Path("/data/dzeiberg/mave_calibration/data/Jia_MSH2_SSM/")
assert dataset_path.exists()

# %%
data = pd.read_csv(dataset_path / "raw" / "urn_mavedb_00000050-a-1_scores.csv")

# %%
data.head()
# Out:
#                    accession  hgvs_nt  hgvs_splice   hgvs_pro     score  \
# 0  urn:mavedb:00000050-a-1#1      NaN          NaN  p.Met1Ala -0.079522
# 1  urn:mavedb:00000050-a-1#2      NaN          NaN  p.Met1Cys       NaN
# 2  urn:mavedb:00000050-a-1#3      NaN          NaN  p.Met1Tyr -2.870684
# 3  urn:mavedb:00000050-a-1#4      NaN          NaN  p.Met1Trp -3.991671
# 4  urn:mavedb:00000050-a-1#5      NaN          NaN  p.Met1Val -1.395361
#
#             mavedb_clnsig         mavedb_clnrevstat
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4  Uncertain_significance  reviewed_by_expert_panel

# %%
data[data.score.isna()]
# Out:
#                            accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 1          urn:mavedb:00000050-a-1#2      NaN          NaN    p.Met1Cys
# 12        urn:mavedb:00000050-a-1#13      NaN          NaN    p.Met1Glu
# 13        urn:mavedb:00000050-a-1#14      NaN          NaN    p.Met1Phe
# 36        urn:mavedb:00000050-a-1#37      NaN          NaN    p.Ala2Trp
# 42        urn:mavedb:00000050-a-1#43      NaN          NaN    p.Val3Gln
# ...                              ...      ...          ...          ...
# 17682  urn:mavedb:00000050-a-1#17683      NaN          NaN  p.Lys931Gln
# 17687  urn:mavedb:00000050-a-1#17688      NaN          NaN  p.Lys931Cys
# 17710  urn:mavedb:00000050-a-1#17711      NaN          NaN  p.Thr933Trp
# 17718  urn:mavedb:00000050-a-1#17719      NaN          NaN  p.Thr933Lys
# 17732  urn:mavedb:00000050-a-1#17733      NaN          NaN  p.Thr934Met
#
#        score                                 mavedb_clnsig  \
# 1        NaN                                           NaN
# 12       NaN                                           NaN
# 13       NaN                                           NaN
# 36       NaN                                           NaN
# 42       NaN                                           NaN
# ...      ...                                           ...
# 17682    NaN                                           NaN
# 17687    NaN                                           NaN
# 17710    NaN                                           NaN
# 17718    NaN                                           NaN
# 17732    NaN  Conflicting_interpretations_of_pathogenicity
#
#                                     mavedb_clnrevstat
# 1                                                 NaN
# 12                                                NaN
# 13                                                NaN
# 36                                                NaN
# 42                                                NaN
# ...                                               ...
# 17682                                             NaN
# 17687                                             NaN
# 17710                                             NaN
# 17718                                             NaN
# 17732  criteria_provided,_conflicting_interpretations
#
# [997 rows x 7 columns]

# %%
data = data.dropna(subset=['score'])

# %%
data
# Out:
#                            accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0          urn:mavedb:00000050-a-1#1      NaN          NaN    p.Met1Ala
# 2          urn:mavedb:00000050-a-1#3      NaN          NaN    p.Met1Tyr
# 3          urn:mavedb:00000050-a-1#4      NaN          NaN    p.Met1Trp
# 4          urn:mavedb:00000050-a-1#5      NaN          NaN    p.Met1Val
# 5          urn:mavedb:00000050-a-1#6      NaN          NaN    p.Met1Thr
# ...                              ...      ...          ...          ...
# 17741  urn:mavedb:00000050-a-1#17742      NaN          NaN  p.Thr934Cys
# 17742  urn:mavedb:00000050-a-1#17743      NaN          NaN  p.Thr934Tyr
# 17743  urn:mavedb:00000050-a-1#17744      NaN          NaN  p.Thr934Ala
# 17744  urn:mavedb:00000050-a-1#17745      NaN          NaN  p.Thr934Lys
# 17745  urn:mavedb:00000050-a-1#17746      NaN          NaN  p.Thr934Trp
#
#           score                                 mavedb_clnsig  \
# 0     -0.079522                                           NaN
# 2     -2.870684                                           NaN
# 3     -3.991671                                           NaN
# 4     -1.395361                        Uncertain_significance
# 5      0.301806                                           NaN
# ...         ...                                           ...
# 17741 -2.485740                                           NaN
# 17742 -4.022393                                           NaN
# 17743 -3.004477                                           NaN
# 17744 -4.976463  Conflicting_interpretations_of_pathogenicity
# 17745 -2.440222                                           NaN
#
#                                     mavedb_clnrevstat
# 0                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                            reviewed_by_expert_panel
# 5                                                 NaN
# ...                                               ...
# 17741                                             NaN
# 17742                                             NaN
# 17743                                             NaN
# 17744  criteria_provided,_conflicting_interpretations
# 17745                                             NaN
#
# [16749 rows x 7 columns]

# %%
data.to_csv(dataset_path / 'scoreset.csv', index=False)

# %%
metadata = dict(uniprot_acc='P43246')
with open(dataset_path / 'metadata.json', 'w') as f:
    json.dump(metadata, f)

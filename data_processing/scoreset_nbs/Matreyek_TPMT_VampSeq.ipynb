# %%
import pandas as pd
from pathlib import Path
import json
dataset_path = Path("/mnt/i/bio/mave_curation/Matreyek_TPMT_VampSeq/")
assert dataset_path.exists()

# %%
data = pd.read_csv(dataset_path / "raw" / "urn_mavedb_00000013-b-1_scores.csv")

# %%
data = data[data.hgvs_pro.str.contains("p.")]

# %%
data
# Out:
#                          accession  hgvs_nt  hgvs_splice    hgvs_pro  \
# 0        urn:mavedb:00000013-b-1#1      NaN          NaN   p.Met1Ala
# 1        urn:mavedb:00000013-b-1#2      NaN          NaN   p.Met1Gln
# 2        urn:mavedb:00000013-b-1#3      NaN          NaN   p.Thr6Met
# 3        urn:mavedb:00000013-b-1#4      NaN          NaN  p.Ser61Pro
# 4        urn:mavedb:00000013-b-1#5      NaN          NaN  p.Ser61Gln
# ...                            ...      ...          ...         ...
# 4023  urn:mavedb:00000013-b-1#4024      NaN          NaN  p.Ser61Glu
# 4024  urn:mavedb:00000013-b-1#4025      NaN          NaN  p.Ser61Ile
# 4025  urn:mavedb:00000013-b-1#4026      NaN          NaN  p.Ser61Lys
# 4026  urn:mavedb:00000013-b-1#4027      NaN          NaN  p.Ser61Leu
# 4027  urn:mavedb:00000013-b-1#4028      NaN          NaN  p.Ser61Met
#
#          score        sd  expts        se  lower_ci  upper_ci  ...  \
# 0     1.182418  0.301024    6.0  0.122893  0.941553  1.423283  ...
# ...

# %%
scoreset = data.to_csv(dataset_path / 'scoreset.csv', index=False)

# %%
metadata = dict(uniprot_acc='P51580')
with open(dataset_path / 'metadata.json', 'w') as f:
    json.dump(metadata, f)

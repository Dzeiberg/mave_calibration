# %%
import pandas as pd
from pathlib import Path
import json
dataset_path = Path("/mnt/i/bio/mave_curation/Starita_BRCA1_HDR/")
assert dataset_path.exists()
data = pd.read_csv(dataset_path/ "raw" / "TableS6.tsv",delimiter='\t')

# %%
data
# Out:
#       brca1_sort1_noGFP_counts  brca1_sort1_score  brca1_sort2_GFP_counts  \
# 1                     316875.0          -0.007125                516108.0
# 2                     183730.0           0.000000                300303.0
# 3                       3045.0          -0.520791                  2653.0
# 4                          NaN                NaN                     NaN
# 5                          NaN                NaN                     NaN
# ...                        ...                ...                     ...
# 3072                     693.0          -0.123354                  2302.0
# 3073                    1003.0           0.050326                  4675.0
# 3074                     212.0          -0.190518                   762.0
# 3075                      19.0          -0.251326                   648.0
# 3076                      67.0           0.434266                    36.0
#
#       brca1_sort2_noGFP_counts  brca1_sort2_score  brca1_sort3_GFP_counts  \
# 1                     608958.0           0.022115                135695.0
# 2                     362252.0           0.000000                 83040.0
# 3                       4213.0          -0.274866                  1419.0
# 4                          NaN                NaN                     NaN
# 5                          NaN                NaN                    97.0
# ...                        ...                ...                     ...
# 3072                     282.0          -0.154020                   462.0
# 3073                     594.0          -0.189721                   813.0
# 3074                     132.0          -0.502072                   140.0
# 3075                      14.0           1.548421                     NaN
# 3076                      24.0          -1.853453                    35.0
#
#       brca1_sort3_noGFP_counts  brca1_sort3_score  brca1_sort4_GFP_counts  \
# 1                     190230.0           0.069236                312773.0
# 2                     124759.0           0.000000                193322.0
# 3                       2778.0          -0.264547                  5011.0
# 4                          NaN                NaN                     NaN
# 5                          NaN                NaN                     NaN
# ...                        ...                ...                     ...
# 3072                     864.0          -0.103272                   718.0
# 3073                    1447.0          -0.054015                  1068.0
# 3074                     319.0          -0.299317                   251.0
# 3075                      59.0                NaN                    29.0
# 3076                      55.0           0.075382                   134.0
#
#       brca1_sort4_noGFP_counts  ...  sort3_brca1_sigcol05  \
# 1                     181988.0  ...                 black
# 2                     115709.0  ...                 black
# 3                       2567.0  ...                 black
# 4                          NaN  ...                 black
# 5                         24.0  ...                 black
# ...                        ...  ...                   ...
# 3072                     309.0  ...                 black
# 3073                     666.0  ...                 black
# 3074                     119.0  ...                 black
# 3075                       1.0  ...                 black
# 3076                      53.0  ...                 black
#
#       control_sort3_score_pvals  control_sort3_score_qvals  \
# 1                      0.395074                   0.989235
# 2                      1.000000                   1.000000
# 3                      0.175456                   0.989235
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# ...                         ...                        ...
# 3072                   0.733368                   0.991817
# 3073                   0.434932                   0.991817
# 3074                   0.797307                   0.991817
# 3075                   0.937427                   0.999071
# 3076                   0.992846                   0.999581
#
#       sort3_control_sigcol05  brca1_sort4_score_pvals  \
# 1                      black                 0.586477
# 2                      black                 1.000000
# 3                      black                 0.571258
# 4                      black                      NaN
# 5                      black                      NaN
# ...                      ...                      ...
# 3072                   black                 0.133974
# 3073                   black                 0.631582
# 3074                   black                 0.442372
# 3075                   black                 0.555970
# 3076                   black                 0.436641
#
#       brca1_sort4_score_qvals  sort4_brca1_sigcol05  \
# 1                    0.658897                 black
# 2                    0.805790                 black
# 3                    0.653329                 black
# 4                         NaN                 black
# 5                         NaN                 black
# ...                       ...                   ...
# 3072                 0.750144                 black
# 3073                 0.942233                 black
# 3074                 0.916822                 black
# 3075                 0.936163                 black
# 3076                 0.916822                 black
#
#       control_sort4_score_pvals  control_sort4_score_qvals  \
# 1                      0.677612                   0.984090
# 2                      1.000000                   1.000000
# 3                      0.570258                   0.981233
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# ...                         ...                        ...
# 3072                   0.198100                   0.951081
# 3073                   0.128400                   0.951081
# 3074                   0.808351                   0.951081
# 3075                        NaN                        NaN
# 3076                   0.490315                   0.951081
#
#       sort4_control_sigcol05
# 1                      black
# 2                      black
# 3                      black
# 4                      black
# 5                      black
# ...                      ...
# 3072                   black
# 3073                   black
# 3074                   black
# 3075                   black
# 3076                   black
#
# [3076 rows x 54 columns]

# %%
data.columns
# Out:
# Index(['brca1_sort1_noGFP_counts', 'brca1_sort1_score',
#        'brca1_sort2_GFP_counts', 'brca1_sort2_noGFP_counts',
#        'brca1_sort2_score', 'brca1_sort3_GFP_counts',
#        'brca1_sort3_noGFP_counts', 'brca1_sort3_score',
#        'brca1_sort4_GFP_counts', 'brca1_sort4_noGFP_counts',
#        'brca1_sort4_score', 'brca_sort1_GFP_counts',
#        'control_sort1_GFP_counts', 'control_sort1_noGFP_counts',
#        'control_sort1_score', 'control_sort2_GFP_counts',
#        'control_sort2_noGFP_counts', 'control_sort2_score',
#        'control_sort3_GFP_counts', 'control_sort3_noGFP_counts',
#        'control_sort3_score', 'control_sort4_GFP_counts',
#        'control_sort4_noGFP_counts', 'control_sort4_score', 'pool', 'variant',
#        'protPos', 'mut', 'WT', 'bins', 'brca1_sort1_score_pvals',
#        'brca1_sort1_score_qvals', 'sort1_brca1_sigcol05',
#        'control_sort1_score_pvals', 'control_sort1_score_qvals',
#        'sort1_control_sigcol05', 'brca1_sort2_score_pvals',
#        'brca1_sort2_score_qvals', 'sort2_brca1_sigcol05',
#        'control_sort2_score_pvals', 'control_sort2_score_qvals',
#        'sort2_control_sigcol05', 'brca1_sort3_score_pvals',
#        'brca1_sort3_score_qvals', 'sort3_brca1_sigcol05',
#        'control_sort3_score_pvals', 'control_sort3_score_qvals',
#        'sort3_control_sigcol05', 'brca1_sort4_score_pvals',
#        'brca1_sort4_score_qvals', 'sort4_brca1_sigcol05',
#        'control_sort4_score_pvals', 'control_sort4_score_qvals',
#        'sort4_control_sigcol05'],
#       dtype='object')

# %%
data.variant
# Out:
# 1               _sy
# 2               _wt
# 3       p.Ala102Val
# 4       p.Ala108Ser
# 5       p.Ala134Thr
#            ...
# 3072    p.Val191Thr
# 3073    p.Val191Trp
# 3074    p.Val191Tyr
# 3075    p.Val299His
# 3076    p.Val299Trp
# Name: variant, Length: 3076, dtype: object

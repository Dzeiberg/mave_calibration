# %%
import pandas as pd
pd.set_option('display.max_columns', None)
from pathlib import Path
import json
dataset_path = Path("/mnt/i/bio/mave_curation/Starita_BRCA1_HDR/")
assert dataset_path.exists()
data = pd.read_csv(dataset_path/ "raw" / "urn_mavedb_00000081-a-2_scores.csv")

# %%
data
# Out:
#                          accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0        urn:mavedb:00000081-a-2#1      NaN          NaN    p.Val8Trp
# 1        urn:mavedb:00000081-a-2#2      NaN          NaN    p.Val8Ser
# 2        urn:mavedb:00000081-a-2#3      NaN          NaN    p.Val8Pro
# 3        urn:mavedb:00000081-a-2#4      NaN          NaN    p.Val8Met
# 4        urn:mavedb:00000081-a-2#5      NaN          NaN    p.Val8Leu
# ...                            ...      ...          ...          ...
# 2815  urn:mavedb:00000081-a-2#2816      NaN          NaN  p.Ala102Gln
# 2816  urn:mavedb:00000081-a-2#2817      NaN          NaN  p.Ala102Cys
# 2817  urn:mavedb:00000081-a-2#2818      NaN          NaN  p.Ala102Asp
# 2818  urn:mavedb:00000081-a-2#2819      NaN          NaN  p.Ala102Asn
# 2819  urn:mavedb:00000081-a-2#2820      NaN          NaN  p.Ala102Arg
#
#          score  brca1_sort1_score  brca1_sort2_score  brca1_sort3_score  \
# 0     0.109929           0.068393           0.154208           0.160836
# 1     0.314116           0.649407           0.007217           0.310740
# 2    -0.288265          -0.425717           0.588212          -1.004666
# 3     0.214284          -0.315936          -0.115324           0.398803
# 4     0.442821           1.745340                NaN           0.000957
# ...        ...                ...                ...                ...
# 2815 -0.019377           0.113339          -0.199678           0.108144
# 2816  0.076675           0.317509          -0.884260           0.734668
# 2817 -0.086023           0.163494          -0.182905          -0.294175
# 2818  0.206666           0.461364          -0.171476           0.545445
# 2819 -0.132773          -0.056832          -0.348657          -0.065082
#
#       brca1_sort4_score
# 0              0.056280
# 1              0.289100
# 2             -0.310891
# 3              0.889591
# 4             -0.417833
# ...                 ...
# 2815          -0.099313
# 2816           0.138781
# 2817          -0.030509
# 2818          -0.008671
# 2819          -0.060521
#
# [2820 rows x 9 columns]

# %%
data.to_csv(dataset_path / "scoreset.csv", index=False)

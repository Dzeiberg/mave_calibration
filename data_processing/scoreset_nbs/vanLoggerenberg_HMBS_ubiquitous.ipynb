# %%
import pandas as pd
from pathlib import Path
import json
dataset_path = Path("/mnt/i/bio/mave_curation/vanLoggerenberg_HMBS_ubiquitous/")
assert dataset_path.exists()

# %%
data = pd.read_csv(dataset_path / "raw" / "urn_mavedb_00000108-a-1_scores.csv")

# %%
data
# Out:
#                          accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0        urn:mavedb:00000108-a-1#1      NaN          NaN   p.Val94Tyr
# 1        urn:mavedb:00000108-a-1#2      NaN          NaN   p.Val94Trp
# 2        urn:mavedb:00000108-a-1#3      NaN          NaN   p.Val94Thr
# 3        urn:mavedb:00000108-a-1#4      NaN          NaN   p.Val94Ter
# 4        urn:mavedb:00000108-a-1#5      NaN          NaN   p.Val94Ser
# ...                            ...      ...          ...          ...
# 6039  urn:mavedb:00000108-a-1#6040      NaN          NaN  p.Ala112Cys
# 6040  urn:mavedb:00000108-a-1#6041      NaN          NaN  p.Ala112Asp
# 6041  urn:mavedb:00000108-a-1#6042      NaN          NaN  p.Ala112Asn
# 6042  urn:mavedb:00000108-a-1#6043      NaN          NaN  p.Ala112Arg
# 6043  urn:mavedb:00000108-a-1#6044      NaN          NaN    p.Ala112=
#
#          score        sd  df        se
# 0     0.078732  0.240569   2  0.170108
# 1    -0.641036  0.184045   2  0.130139
# ...

# %%
data = data[(~data.hgvs_pro.isna()) & (~data.score.isna())]

# %%
data.to_csv(dataset_path / "scoreset.csv", index=False)

# %%
metadata = dict(uniprot_acc='P08397')
with open(dataset_path / 'metadata.json', 'w') as f:
    json.dump(metadata, f)

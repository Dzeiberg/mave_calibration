# %%
from pathlib import Path
import pandas as pd
import json
import mavehgvs
dataset_path = Path("/mnt/i/bio/mave_curation/Giacomelli_p53_nullNutlin3/")

# %%
data = pd.read_csv(dataset_path / "raw" / "urn_mavedb_00000068-b-1_scores.csv")

# %%
data = data.dropna(subset=["hgvs_pro",'score'])

# %%
data
# Out:
#                          accession  hgvs_nt  hgvs_splice     hgvs_pro  \
# 0        urn:mavedb:00000068-b-1#1      NaN          NaN  p.Asp391Glu
# 1        urn:mavedb:00000068-b-1#2      NaN          NaN  p.Asp391Cys
# 2        urn:mavedb:00000068-b-1#3      NaN          NaN    p.Asp391=
# 3        urn:mavedb:00000068-b-1#4      NaN          NaN  p.Asp391Ala
# 4        urn:mavedb:00000068-b-1#5      NaN          NaN  p.Pro390Ter
# ...                            ...      ...          ...          ...
# 8269  urn:mavedb:00000068-b-1#8270      NaN          NaN    p.Glu3Leu
# 8270  urn:mavedb:00000068-b-1#8271      NaN          NaN    p.Glu3Lys
# 8271  urn:mavedb:00000068-b-1#8272      NaN          NaN    p.Glu3Ile
# 8272  urn:mavedb:00000068-b-1#8273      NaN          NaN    p.Glu3His
# 8273  urn:mavedb:00000068-b-1#8274      NaN          NaN    p.Glu3Gly
#
#          score
# 0    -1.281893
# 1    -1.637839
# 2    -0.886148
# 3    -1.174566
# 4    -1.429412
# ...        ...
# ...

# %%
data.to_csv(dataset_path / 'scoreset.csv', index=False)

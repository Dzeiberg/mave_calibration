# %%
from pathlib import Path
import pandas as pd
import json
import mavehgvs
dataset_path = Path("/mnt/i/bio/mave_curation/Hu_BRCA2_HDR/")

# %%
data = pd.read_excel(dataset_path / "raw" / "1-s2.0-S000292972400034X-mmc2.xlsx",header=1)

# %%
data
# Out:
#                                   Amino acid position  protein change  \
# 0                                                  NaN            NaN
# 1                                                 2483   p.Ser2483Asn
# 2                                                 2484   p.Leu2484His
# 3                                                 2488   p.Arg2488Gly
# 4                                                 2488   p.Arg2488Ser
# ..                                                 ...            ...
# 461                                               3187   p.Asn3187Lys
# 462                                               3191   p.Trp3191Cys
# 463                  RefSeq ID for BRCA2 (NM_000059.3)            NaN
# 464  *: Observed splice defect by Ambry Genetics (u...            NaN
# 465  HDR: Homology directed repair assay (HDR score...            NaN
#
#     protein change2 coding nucleotide change  HDR score  HDR 95% CI lower  \
# 0               NaN                      NaN        NaN               NaN
# 1            S2483N                c.7448G>A   5.093829          4.411474
# 2            L2484H                c.7451T>A   3.776840          3.278966
# 3            R2488G                c.7462A>G   2.919432          2.600069
# 4            R2488S                c.7464A>C   2.964786          2.734104
# ..              ...                      ...        ...               ...
# 461          N3187K                c.9561T>A   4.603071          4.096453
# 462          W3191C                c.9573G>C   3.572944          3.103345
# 463             NaN                      NaN        NaN               NaN
# 464             NaN                      NaN        NaN               NaN
# 465             NaN                      NaN        NaN               NaN
#
#      HDR 95% CI upper HDR function BRCA2 sub-domain  \
# 0                 NaN          NaN              NaN
# 1            5.864636       Normal               HD
# 2            4.346223       Normal               HD
# 3            3.277462       Normal               HD
# 4            3.215886       Normal               HD
# ..                ...          ...              ...
# 461          5.170082       Normal              OB3
# 462          4.108357       Normal              OB3
# 463               NaN          NaN              NaN
# 464               NaN          NaN              NaN
# 465               NaN          NaN              NaN
#
#     Secondary-structure elements  ...              Unnamed: 24  \
# 0                            NaN  ...  SpliceAI summary (>0.2)
# 1                           HDα1  ...                       AG
# 2                           HDα1  ...                        -
# 3                           HDα1  ...                        -
# 4                           HDα1  ...                        -
# ..                           ...  ...                      ...
# 461                            -  ...                        -
# 462                            -  ...                        -
# 463                          NaN  ...                      NaN
# 464                          NaN  ...                      NaN
# 465                          NaN  ...                      NaN
#
#                        Unnamed: 25 BRCA_ML Training set  \
# 0    Splicing effect related notes                  NaN
# 1                                -                  Yes
# 2                                -                   No
# 3                                -                  Yes
# 4                                -                  Yes
# ..                             ...                  ...
# 461                              -                   No
# 462                              -                   No
# 463                            NaN                  NaN
# 464                            NaN                  NaN
# 465                            NaN                  NaN
#
#      Reported in current study (=1) Previous publications Unnamed: 29  \
# 0                               NaN                    10          11
# 1                                 -              5.093829        5.09
# 2                                 -                     -     3.77684
# 3                                 -              2.919432        2.92
# 4                                 -              2.964786        2.96
# ..                              ...                   ...         ...
# 461                               -                     -         4.6
# 462                               1                     -           -
# 463                             NaN                   NaN         NaN
# 464                             NaN                   NaN         NaN
# 465                             NaN                   NaN         NaN
#
#      Unnamed: 30 Unnamed: 31  Unnamed: 32  Unnamed: 33
# 0             12          13           14           15
# 1              -         5.1            -            -
# 2              -           -            -            -
# 3              -        2.92         2.92            -
# 4              -        2.44         2.44            -
# ..           ...         ...          ...          ...
# 461            -           -            -            -
# 462            -           -            -            -
# 463          NaN         NaN          NaN          NaN
# 464          NaN         NaN          NaN          NaN
# 465          NaN         NaN          NaN          NaN
#
# [466 rows x 34 columns]

# %%
data = data.rename(columns={'protein change':'hgvs_pro',
                            'HDR score' : 'score'}).dropna(subset=['hgvs_pro','score'])

# %%
data
# Out:
#     Amino acid position       hgvs_pro protein change2  \
# 1                   2483  p.Ser2483Asn          S2483N
# 2                   2484  p.Leu2484His          L2484H
# 3                   2488  p.Arg2488Gly          R2488G
# 4                   2488  p.Arg2488Ser          R2488S
# 5                   2489  p.Asp2489Tyr          D2489Y
# ..                   ...           ...             ...
# 458                 3180  p.Leu3180Arg          L3180R
# 459                 3183  p.Ile3183Val          I3183V
# 460                 3184  p.Leu3184Pro          L3184P
# 461                 3187  p.Asn3187Lys          N3187K
# 462                 3191  p.Trp3191Cys          W3191C
#
#     coding nucleotide change     score  HDR 95% CI lower  HDR 95% CI upper  \
# 1                  c.7448G>A  5.093829          4.411474          5.864636
# 2                  c.7451T>A  3.776840          3.278966          4.346223
# 3                  c.7462A>G  2.919432          2.600069          3.277462
# 4                  c.7464A>C  2.964786          2.734104          3.215886
# 5                  c.7465G>T  4.581064          3.976894          5.271930
# ..                       ...       ...               ...               ...
# 458                c.9539T>G  2.930243          2.541791          3.378802
# 459                c.9547A>G  4.748876          4.117611          5.468699
# 460                c.9551T>C  3.286415          2.852996          3.783462
# 461                c.9561T>A  4.603071          4.096453          5.170082
# 462                c.9573G>C  3.572944          3.103345          4.108357
#
#     HDR function BRCA2 sub-domain Secondary-structure elements  ...  \
# 1         Normal               HD                         HDα1  ...
# 2         Normal               HD                         HDα1  ...
# 3         Normal               HD                         HDα1  ...
# 4         Normal               HD                         HDα1  ...
# 5         Normal               HD                         HDα1  ...
# ..           ...              ...                          ...  ...
# 458       Normal              OB3                        OB3α3  ...
# 459       Normal              OB3                        OB3α3  ...
# 460       Normal              OB3                        OB3α3  ...
# 461       Normal              OB3                            -  ...
# 462       Normal              OB3                            -  ...
#
#     Unnamed: 24 Unnamed: 25 BRCA_ML Training set  \
# 1            AG           -                  Yes
# 2             -           -                   No
# 3             -           -                  Yes
# 4             -           -                  Yes
# 5             -           -                   No
# ..          ...         ...                  ...
# 458           -           -                   No
# 459           -           -                   No
# 460           -           -                   No
# 461           -           -                   No
# 462           -           -                   No
#
#      Reported in current study (=1) Previous publications Unnamed: 29  \
# 1                                 -              5.093829        5.09
# 2                                 -                     -     3.77684
# 3                                 -              2.919432        2.92
# 4                                 -              2.964786        2.96
# 5                                 -                     -    4.581064
# ..                              ...                   ...         ...
# 458                               -                     -    2.930243
# 459                               1                     -           -
# 460                               1                     -           -
# 461                               -                     -         4.6
# 462                               1                     -           -
#
#      Unnamed: 30 Unnamed: 31  Unnamed: 32  Unnamed: 33
# 1              -         5.1            -            -
# 2              -           -            -            -
# 3              -        2.92         2.92            -
# 4              -        2.44         2.44            -
# 5              -           -            -            -
# ..           ...         ...          ...          ...
# 458            -           -            -            -
# 459            -           -            -            -
# 460            -           -            -            -
# 461            -           -            -            -
# 462            -           -            -            -
#
# [462 rows x 34 columns]

# %%
data.to_csv(dataset_path / "scoreset.csv",index=False)

# %%
metadata = dict(uniprot_acc='P51587')
with open(dataset_path / "metadata.json","w") as f:
    json.dump(metadata,f)

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
scoreset = pd.read_csv('/mnt/i/bio/mave_curation/Erwood_BRCA2_HEK293T/hgvs_nuc_scoreset.csv')

# %%
scoreset
# Out:
#     Protein Annotation Wild type Base Edited Base   CDS Consequence  \
# 0               T2515T              A           C  7545  synonymous
# 1               T2515T              A           T  7545  synonymous
# 2               T2515T              A           G  7545  synonymous
# 3               S2516T              T           A  7546    missense
# 4               S2516P              T           C  7546    missense
# ..                 ...            ...         ...   ...         ...
# 421             T1155T              T           C  3465  synonymous
# 422             T1155T              T           G  3465  synonymous
# 423             S1156T              T           A  3466    missense
# 424             S1156P              T           C  3466    missense
# 425             S1156A              T           G  3466    missense
#
#     SPE Classification  Function Score                           id     start  \
# 0           Functional        0.999369  chr13-32356536-32356537-A-C  32356536
# 1           Functional        0.995782  chr13-32356536-32356537-A-T  32356536
# 2           Functional        0.957546  chr13-32356536-32356537-A-G  32356536
# 3           Functional        1.006952  chr13-32356537-32356538-T-A  32356537
# 4           Functional        0.960612  chr13-32356537-32356538-T-C  32356537
# ..                 ...             ...                          ...       ...
# 421         Functional        0.984006  chr13-32337819-32337820-T-C  32337819
# 422         Functional        1.022418  chr13-32337819-32337820-T-G  32337819
# 423         Functional        1.041031  chr13-32337820-32337821-T-A  32337820
# 424         Functional        1.028343  chr13-32337820-32337821-T-C  32337820
# 425         Functional        1.031166  chr13-32337820-32337821-T-G  32337820
#
#           end reference_base alternate_base  \
# 0    32356537              A              C
# 1    32356537              A              T
# 2    32356537              A              G
# 3    32356538              T              A
# 4    32356538              T              C
# ..        ...            ...            ...
# 421  32337820              T              C
# 422  32337820              T              G
# 423  32337821              T              A
# 424  32337821              T              C
# 425  32337821              T              G
#
#                                            refseq_id    Clinvar_SIG  \
# 0    BRCA2:NM_000059:exon15:c.A7545C:p.T2515T:Select            NaN
# 1    BRCA2:NM_000059:exon15:c.A7545T:p.T2515T:Select            NaN
# 2    BRCA2:NM_000059:exon15:c.A7545G:p.T2515T:Select  Likely_benign
# 3    BRCA2:NM_000059:exon15:c.T7546A:p.S2516T:Select            NaN
# 4    BRCA2:NM_000059:exon15:c.T7546C:p.S2516P:Select            NaN
# ..                                               ...            ...
# 421  BRCA2:NM_000059:exon11:c.T3465C:p.T1155T:Select  Likely_benign
# 422  BRCA2:NM_000059:exon11:c.T3465G:p.T1155T:Select            NaN
# 423  BRCA2:NM_000059:exon11:c.T3466A:p.S1156T:Select            NaN
# 424  BRCA2:NM_000059:exon11:c.T3466C:p.S1156P:Select            NaN
# 425  BRCA2:NM_000059:exon11:c.T3466G:p.S1156A:Select            NaN
#
#      CADD_phred  Unadjusted Function Score symbol transcript    exon  \
# 0           NaN                   0.003596  BRCA2  NM_000059  exon15
# 1           NaN                   0.009437  BRCA2  NM_000059  exon15
# 2           NaN                   0.108622  BRCA2  NM_000059  exon15
# 3         26.20                  -0.016045  BRCA2  NM_000059  exon15
# 4         28.10                   0.098578  BRCA2  NM_000059  exon15
# ..          ...                        ...    ...        ...     ...
# 421       12.04                   0.032910  BRCA2  NM_000059  exon11
# 422       11.75                  -0.047259  BRCA2  NM_000059  exon11
# 423       16.72                  -0.082471  BRCA2  NM_000059  exon11
# 424       23.60                  -0.055343  BRCA2  NM_000059  exon11
# 425       20.90                  -0.061009  BRCA2  NM_000059  exon11
#
#       hgvs_nuc      hgvs_pro  select
# 0    c.7545A>C  p.Thr2515Thr  Select
# 1    c.7545A>T  p.Thr2515Thr  Select
# 2    c.7545A>G  p.Thr2515Thr  Select
# 3    c.7546T>A  p.Ser2516Thr  Select
# 4    c.7546T>C  p.Ser2516Pro  Select
# ..         ...           ...     ...
# 421  c.3465T>C  p.Thr1155Thr  Select
# 422  c.3465T>G  p.Thr1155Thr  Select
# 423  c.3466T>A  p.Ser1156Thr  Select
# 424  c.3466T>C  p.Ser1156Pro  Select
# 425  c.3466T>G  p.Ser1156Ala  Select
#
# [426 rows x 22 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
import numpy as np
import swifter
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
clinvar_variant_summary = pd.read_csv("/mnt/d/mave_calibration/cache/variant_summary_2024-08.txt.gz",delimiter="\t",compression='gzip')

# %%
clinvar_variant_summary.to_pickle("/mnt/d/mave_calibration/cache/variant_summary_2024-08.pkl")

# %%
clinvar_variant_summary.shape

# %% [markdown]
# # Filter only single nucleotide variant

# %%
clinvar_snv = clinvar_variant_summary[clinvar_variant_summary['Type']=='single nucleotide variant']

# %%
clinvar_snv.shape

# %%
import re
from Bio.PDB.Polypeptide import protein_letters_3to1, protein_letters_3to1_extended
residues = set(list(map(lambda k : k.title(), protein_letters_3to1.keys())))

def parse_protein_variant(s):
    """
    Parse protein conseequence of a variant

    Parameters
    ----------
    s : str
        The input string to parse
    
    Returns
    -------
    reference_aa : str
    """
    # SPECIAL CASE: no protein
    if s == "p.0":
        raise ValueError("No protein")
    
    # Define a regular expression pattern to match the number in the string
    pattern = re.compile(r'(\D*)(\d+)(\D*)')
    
    # Search for the pattern in the input string
    match = pattern.search(s)
    
    if match:
        # Extract the three parts from the match groups
        before_number = match.group(1)
        number = match.group(2)
        after_number = match.group(3)
        wt_aa = before_number.replace("p.","")
        after_number = after_number.replace(")","")
        if wt_aa not in residues and wt_aa not in set(("Ter","Sec","Pyl")):
            raise ValueError(f"Expecting the value before the number to be a residue, not '{wt_aa}', as found in '{s}'")
        try:
            number = int(number)
        except:
            raise ValueError(f"Cannot convert {number} to an integer")
        if after_number[0] == "_":
            raise ValueError("Looks like variant causes a new translation initiation site")
        if "ext" in after_number:
            raise ValueError("Looks like an extension")
        if "^" in after_number:
            raise ValueError("Uncertain")
        if "/" in after_number:
            raise ValueError("Mosaic")
        return wt_aa, number, after_number
    else:
        # Return the original string if no number is found
        raise ValueError("Not a supported protein variant")

def is_protein_variant(name):
    return "(p." in name

def is_silent(name):
    if not is_protein_variant(name):
        return False
    protein_variant = name.split("p.")[1]
    try:
        wt_aa, position, variant = parse_protein_variant(protein_variant)
    except ValueError:
        return False
    return variant == "="

def is_nonsense(name):
    if not is_protein_variant(name):
        return False
    protein_variant = name.split("p.")[1]
    try:
        wt_aa, position, variant = parse_protein_variant(protein_variant)
    except ValueError:
        return False
    if variant == "*":
        return True
    if variant == "Ter":
        return True
    return False

def is_unknown(name):
    if not is_protein_variant(name):
        return False
    protein_variant = name.split("p.")[1]
    try:
        wt_aa, position, variant = parse_protein_variant(protein_variant)
    except ValueError:
        return False
    return variant == "?" or variant == "Xaa"

def is_missense(name):
    if not is_protein_variant(name):
        return False
    protein_variant = name.split("p.")[1]
    try:
        wt_aa, position, variant = parse_protein_variant(protein_variant)
    except ValueError:
        return False
    return variant in residues

def is_other_protein_variant(name):
    if not is_protein_variant(name):
        return False
    protein_variant = name.split("p.")[1]
    try:
        wt_aa, position, variant = parse_protein_variant(protein_variant)
    except ValueError:
        return True
    return variant not in {"=", "*", "Ter", "?", "Xaa"} and variant not in residues

# %% [markdown]
# a few tests of parse protein variant

# %%
parse_protein_variant("p.Ala123Thr")

# %%
parse_protein_variant("p.Ala123Ter"), parse_protein_variant("p.Ala123*")

# %%
parse_protein_variant("p.Leu2_Met124del"), parse_protein_variant("p.Met1_Leu2insArgSerThrVal")

# %%
parse_protein_variant("p.Ter327Arg")

# %% [markdown]
# # Non-protein variants

# %%
nonprotein_variant_mask = clinvar_snv['Name'].apply(lambda x: not is_protein_variant(x))

# %%
nonprotein_variant_mask.sum()

# %%
clinvar_snv[nonprotein_variant_mask].iloc[0].Name

# %% [markdown]
# # Missense Variants

# %%
missense_mask = clinvar_snv.Name.swifter.apply(is_missense)

# %%
clinvar_missense = clinvar_snv[missense_mask]

# %%
clinvar_missense.shape

# %%
clinvar_missense.iloc[0].Name

# %% [markdown]
# # Silent Variants

# %%
silent_mask = clinvar_snv.Name.swifter.apply(is_silent)
clinvar_silent = clinvar_snv[silent_mask]

# %%
silent_mask.sum()

# %%
clinvar_snv[silent_mask].iloc[0].Name

# %%
clinvar_silent[clinvar_silent.ClinicalSignificance.isin(set(("Pathogenic", "Likely pathogenic", "Pathogenic/Likely pathogenic"))) & \
               ~clinvar_silent.ReviewStatus.isin({'no clasification provided',
                                                  'no assertion criteria provided',
                                                  'no classification for the single variant'})].shape

# %% [markdown]
# # Nonsense

# %%
nonsense_mask = clinvar_snv.Name.swifter.apply(is_nonsense)
clinvar_snv[nonsense_mask].shape

# %%
clinvar_snv[nonsense_mask].iloc[0].Name

# %% [markdown]
# # Unknown Alt-AA

# %%
unknown_mask = clinvar_snv.Name.swifter.apply(is_unknown)
clinvar_snv[unknown_mask].shape

# %%
clinvar_snv[unknown_mask].iloc[0].Name

# %% [markdown]
# # Other cases (e.g. extensions)

# %%
other_protein_variant_mask = clinvar_snv.Name.swifter.apply(is_other_protein_variant)
clinvar_snv[other_protein_variant_mask].shape

# %%
clinvar_snv[other_protein_variant_mask].iloc[0].Name

# %% [markdown]
# # Check that all SNVs are accounted for and all categorizations are mutually exclusive

# %%
clinvar_snv.shape[0], (missense_mask | silent_mask | nonsense_mask | unknown_mask | other_protein_variant_mask | nonprotein_variant_mask).sum().item()

# %%
(np.stack([missense_mask, silent_mask, nonsense_mask, unknown_mask, other_protein_variant_mask, nonprotein_variant_mask], axis=1).sum(axis=1) == 1).all()

# %% [markdown]
# # Summary

# %%
categorization = pd.Series(dict(missense=missense_mask.sum(),
                silent=silent_mask.sum(),
                nonsense=nonsense_mask.sum(),
                unknown=unknown_mask.sum(),
                other=other_protein_variant_mask.sum(),
                non_protein_variant=nonprotein_variant_mask.sum())).sort_values()

# %%
categorization

# %%
def is_valid_refseq_accession(refseq_string):
    """
    Check if a string is a valid RefSeq nucleotide accession number.

    Args:
        refseq_string (str): The string to verify.

    Returns:
        bool: True if the string is a valid RefSeq nucleotide accession, False otherwise.
    """
    # Regular expression pattern for RefSeq nucleotide accession (with optional version)
    # pattern = re.compile(r'^(NM|NP|NR|NG|NC|NT|XM|XP|XR|XT|NC|NG|NT|NR)_\d{6,10}(\.\d+)?$')
    
    # Regular expression pattern for RefSeq nucleotide accession (with required version)
    pattern = re.compile(r'^(NM|NP|NR|NG|NC|NT|XM|XP|XR|XT|NC|NG|NT|NR)_\d{6,10}(\.)(\d+)?$')
    
    # Check if the string matches the pattern
    try:
        return bool(pattern.match(refseq_string))
    except TypeError:
        raise TypeError(f"Expected a string, but got {type(refseq_string)}")

# %%
import re

def parse_clinvar_record(clinvar_string):
    """
    Extract transcript, gene symbol (if exists), DNA sequence substitution, and protein substitution (if exists) from a ClinVar record name.
    
    Args:
        clinvar_string (str): The ClinVar record name (e.g., "NM_015697.9(COQ2):c.30G>A (p.Arg10_Lys11=)" or "c.30G>A (p.Arg10_Lys11=)" or "NM_015697.9:c.30G>A" or "NM_015697.9(COQ2):c.30G>A").
    
    Returns:
        dict: A dictionary containing 'transcript', 'gene_symbol', 'dna_substitution', and 'protein_substitution'.
    """
    # Regular expression pattern to match the ClinVar record format with optional transcript, gene symbol, and protein substitution
    pattern = re.compile(
        r'(?:(?P<transcript>NM_\d+\.\d+|\w+_\d+))?(?:\s*(?:\((?P<gene_symbol>[^\)]+)\)|(?P<gene_symbol_no_paren>[^\s:]+)))?:(?P<dna_substitution>c\.[^\s]+)(?:\s*\((?P<protein_substitution>p\.[^\)]+)\))?'
    )
    
    # Search for the pattern in the input string
    match = pattern.search(clinvar_string)
    
    if match:
        # Extract the parts from the match groups
        transcript = match.group('transcript') or ''
        gene_symbol = match.group('gene_symbol') or match.group('gene_symbol_no_paren') or ''
        dna_substitution = match.group('dna_substitution')
        protein_substitution = match.group('protein_substitution') or ''
        
        return {
            'transcript': transcript,
            'gene_symbol': gene_symbol,
            'dna_substitution': dna_substitution,
            'protein_substitution': protein_substitution
        }
    else:
        # Return None or raise an error if the format is incorrect
        return {
            'transcript': '',
            'gene_symbol': '',
            'dna_substitution': '',
            'protein_substitution': ''}

# Example usage
clinvar_strings = [
    "NM_015697.9(COQ2):c.30G>A (p.Arg10_Lys11=)",
    "NM_015697.9:c.30G>A (p.Arg10_Lys11=)",
    "c.30G>A (p.Arg10_Lys11=)", # X
    "NM_000038.5(GENE):c.123A>T (p.Asn41=)",
    "NM_000038.5:c.123A>T (p.Asn41=)",
    "c.123A>T (p.Asn41=)", # X
    "NM_015697.9:c.30G>A (p.Arg10_Lys11=)",
    "FOXRED1: (p.Arg10_Lys11=)", # X
    "NM_015697.9(COQ2):c.30G>A",  # Protein substitution missing
    "NM_015697.9(ABC):c.30G>A",         # Protein substitution and gene symbol missing
    "NC_000023.10:c.33038255C>A",
    "NG_023416.2:g.(88604_176551)_(176714_576894)del" # X
]

for clinvar_string in clinvar_strings:
    try:
        parsed_result = parse_clinvar_record(clinvar_string)
        print(parsed_result)
    except ValueError as e:
        print(e)

# %%
missense_parse = clinvar_snv[clinvar_snv.Name.swifter.apply(is_missense)].Name.swifter.apply(parse_clinvar_record)

# %%
missense_parse_df = pd.DataFrame([d for d in missense_parse],)

# %%
missense_parse_df

# %%
clinvar_silent_parse = clinvar_snv[silent_mask].Name.swifter.apply(parse_clinvar_record)

# %%
silent_parse_df = pd.DataFrame([d for d in clinvar_silent_parse],)

# %%
silent_parse_df

# %%
fail_cases = clinvar_variant_summary[(clinvar_variant_summary.Type == "single nucleotide variant") & (clinvar_variant_summary.Name.swifter.apply(parse_clinvar_record).str.len() == 0)]

# %%
fail_cases.Name.shape

# %%
parse_res = [d for d in clinvar_snv.Name.swifter.apply(parse_clinvar_record) if len(d)]

# %%
parse_res = pd.DataFrame.from_records(parse_res)

# %%
from data_processing.clinvar import getClinvar, parse_clinvar_name
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
out = getClinvar(use_cached_processed_file=False, cache_dir="/mnt/d/mave_calibration/cache",debug=True)
# Out:
# loading variant summary pickle
# loaded

# %%
out[0]
# Out:
#          #AlleleID                       Type  \
# 4          15043.0  single nucleotide variant
# 5          15043.0  single nucleotide variant
# 6          15044.0  single nucleotide variant
# 7          15044.0  single nucleotide variant
# 8          15045.0  single nucleotide variant
# ...            ...                        ...
# 4236947        NaN                        NaN
# 4236994        NaN                        NaN
# 4236995        NaN                        NaN
# 4237374        NaN                        NaN
# 4237375        NaN                        NaN
#
#                                                  Name GeneID GeneSymbol  \
# 4        NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)   9640     ZNF592
# 5        NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)   9640     ZNF592
# 6         NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)  55572    FOXRED1
# 7         NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)  55572    FOXRED1
# 8        NM_017547.4(FOXRED1):c.1289A>G (p.Asn430Ser)  55572    FOXRED1
# ...                                               ...    ...        ...
# 4236947                                           NaN    NaN        NaN
# 4236994                                           NaN    NaN        NaN
# 4236995                                           NaN    NaN        NaN
# 4237374                                           NaN    NaN        NaN
# 4237375                                           NaN    NaN        NaN
#
#             HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 4        HGNC:28986  Uncertain significance            0.0  Jun 29, 2015
# 5        HGNC:28986  Uncertain significance            0.0  Jun 29, 2015
# 6        HGNC:26927              Pathogenic            0.0  Dec 01, 2023
# 7        HGNC:26927              Pathogenic            0.0  Dec 01, 2023
# 8        HGNC:26927              Pathogenic            0.0  Oct 01, 2010
# ...             ...                     ...            ...           ...
# 4236947         NaN                     NaN            NaN           NaN
# 4236994         NaN                     NaN            NaN           NaN
# 4236995         NaN                     NaN            NaN           NaN
# 4237374         NaN                     NaN            NaN           NaN
# 4237375         NaN                     NaN            NaN           NaN
#
#          RS# (dbSNP) nsv/esv (dbVar)  \
# 4        150829393.0               -
# 5        150829393.0               -
# 6        267606829.0               -
# 7        267606829.0               -
# 8        267606830.0               -
# ...              ...             ...
# 4236947          NaN             NaN
# 4236994          NaN             NaN
# 4236995          NaN             NaN
# 4237374          NaN             NaN
# 4237375          NaN             NaN
#
#                                               RCVaccession  \
# 4                                             RCV000000014
# 5                                             RCV000000014
# 6        RCV000000015|RCV000578659|RCV001194045|RCV0033...
# 7        RCV000000015|RCV000578659|RCV001194045|RCV0033...
# 8                                             RCV000000016
# ...                                                    ...
# 4236947                                                NaN
# 4236994                                                NaN
# 4236995                                                NaN
# 4237374                                                NaN
# 4237375                                                NaN
#
#                                               PhenotypeIDS  \
# 4        MONDO:MONDO:0033005,MedGen:C4551772,OMIM:25130...
# 5        MONDO:MONDO:0033005,MedGen:C4551772,OMIM:25130...
# 6        MONDO:MONDO:0032624,MedGen:C4748791,OMIM:61824...
# 7        MONDO:MONDO:0032624,MedGen:C4748791,OMIM:61824...
# 8          MONDO:MONDO:0032624,MedGen:C4748791,OMIM:618241
# ...                                                    ...
# 4236947                                                NaN
# 4236994                                                NaN
# 4236995                                                NaN
# 4237374                                                NaN
# 4237375                                                NaN
#
#                                              PhenotypeList            Origin  \
# 4                                Galloway-Mowat syndrome 1          germline
# 5                                Galloway-Mowat syndrome 1          germline
# 6        Mitochondrial complex 1 deficiency, nuclear ty...  germline;unknown
# 7        Mitochondrial complex 1 deficiency, nuclear ty...  germline;unknown
# 8        Mitochondrial complex 1 deficiency, nuclear ty...          germline
# ...                                                    ...               ...
# 4236947                                                NaN               NaN
# 4236994                                                NaN               NaN
# 4236995                                                NaN               NaN
# 4237374                                                NaN               NaN
# 4237375                                                NaN               NaN
#
#         OriginSimple Assembly ChromosomeAccession Chromosome        Start  \
# 4           germline   GRCh37         NC_000015.9         15   85342440.0
# 5           germline   GRCh38        NC_000015.10         15   84799209.0
# 6           germline   GRCh37         NC_000011.9         11  126145284.0
# 7           germline   GRCh38        NC_000011.10         11  126275389.0
# 8           germline   GRCh37         NC_000011.9         11  126147412.0
# ...              ...      ...                 ...        ...          ...
# 4236947          NaN      NaN                 NaN        NaN          NaN
# 4236994          NaN      NaN                 NaN        NaN          NaN
# 4236995          NaN      NaN                 NaN        NaN          NaN
# 4237374          NaN      NaN                 NaN        NaN          NaN
# 4237375          NaN      NaN                 NaN        NaN          NaN
#
#                 Stop ReferenceAllele AlternateAllele Cytogenetic  \
# 4         85342440.0              na              na     15q25.3
# 5         84799209.0              na              na     15q25.3
# 6        126145284.0              na              na     11q24.2
# 7        126275389.0              na              na     11q24.2
# 8        126147412.0              na              na     11q24.2
# ...              ...             ...             ...         ...
# 4236947          NaN             NaN             NaN         NaN
# 4236994          NaN             NaN             NaN         NaN
# 4236995          NaN             NaN             NaN         NaN
# 4237374          NaN             NaN             NaN         NaN
# 4237375          NaN             NaN             NaN         NaN
#
#                                               ReviewStatus  NumberSubmitters  \
# 4                           no assertion criteria provided               1.0
# 5                           no assertion criteria provided               1.0
# 6        criteria provided, multiple submitters, no con...               6.0
# 7        criteria provided, multiple submitters, no con...               6.0
# 8                           no assertion criteria provided               1.0
# ...                                                    ...               ...
# 4236947                                                NaN               NaN
# 4236994                                                NaN               NaN
# 4236995                                                NaN               NaN
# 4237374                                                NaN               NaN
# 4237375                                                NaN               NaN
#
#         Guidelines TestedInGTR  \
# 4                -           N
# 5                -           N
# 6                -           N
# 7                -           N
# 8                -           N
# ...            ...         ...
# 4236947        NaN         NaN
# 4236994        NaN         NaN
# 4236995        NaN         NaN
# 4237374        NaN         NaN
# 4237375        NaN         NaN
#
#                                                   OtherIDs  \
# 4        ClinGen:CA210674,UniProtKB:Q92610#VAR_064583,O...
# 5        ClinGen:CA210674,UniProtKB:Q92610#VAR_064583,O...
# 6                        ClinGen:CA113792,OMIM:613622.0001
# 7                        ClinGen:CA113792,OMIM:613622.0001
# 8        ClinGen:CA113794,UniProtKB:Q96CU9#VAR_064571,O...
# ...                                                    ...
# 4236947                                                NaN
# 4236994                                                NaN
# 4236995                                                NaN
# 4237374                                                NaN
# 4237375                                                NaN
#
#          SubmitterCategories  VariationID  PositionVCF ReferenceAlleleVCF  \
# 4                        1.0          4.0   85342440.0                  G
# 5                        1.0          4.0   84799209.0                  G
# 6                        3.0          5.0  126145284.0                  C
# 7                        3.0          5.0  126275389.0                  C
# 8                        1.0          6.0  126147412.0                  A
# ...                      ...          ...          ...                ...
# 4236947                  NaN          NaN          NaN                NaN
# 4236994                  NaN          NaN          NaN                NaN
# 4236995                  NaN          NaN          NaN                NaN
# 4237374                  NaN          NaN          NaN                NaN
# 4237375                  NaN          NaN          NaN                NaN
#
#         AlternateAlleleVCF SomaticClinicalImpact  \
# 4                        A                     -
# 5                        A                     -
# 6                        T                     -
# 7                        T                     -
# 8                        G                     -
# ...                    ...                   ...
# 4236947                NaN                   NaN
# 4236994                NaN                   NaN
# 4236995                NaN                   NaN
# 4237374                NaN                   NaN
# 4237375                NaN                   NaN
#
#         SomaticClinicalImpactLastEvaluated ReviewStatusClinicalImpact  \
# 4                                        -                          -
# 5                                        -                          -
# 6                                        -                          -
# 7                                        -                          -
# 8                                        -                          -
# ...                                    ...                        ...
# 4236947                                NaN                        NaN
# 4236994                                NaN                        NaN
# 4236995                                NaN                        NaN
# 4237374                                NaN                        NaN
# 4237375                                NaN                        NaN
#
#         Oncogenicity OncogenicityLastEvaluated ReviewStatusOncogenicity  \
# 4                  -                         -                        -
# 5                  -                         -                        -
# 6                  -                         -                        -
# 7                  -                         -                        -
# 8                  -                         -                        -
# ...              ...                       ...                      ...
# 4236947          NaN                       NaN                      NaN
# 4236994          NaN                       NaN                      NaN
# 4236995          NaN                       NaN                      NaN
# 4237374          NaN                       NaN                      NaN
# 4237375          NaN                       NaN                      NaN
#
#         is_pathogenic is_benign         HGVSp   RefSeq_nuc is_missense  \
# 4               False     False  p.Gly1046Arg  NM_014630.3        True
# 5               False     False  p.Gly1046Arg  NM_014630.3        True
# 6                True     False   p.Gln232Ter  NM_017547.4       False
# 7                True     False   p.Gln232Ter  NM_017547.4       False
# 8               False     False   p.Asn430Ser  NM_017547.4        True
# ...               ...       ...           ...          ...         ...
# 4236947           NaN       NaN           NaN          NaN         NaN
# 4236994           NaN       NaN           NaN          NaN         NaN
# 4236995           NaN       NaN           NaN          NaN         NaN
# 4237374           NaN       NaN           NaN          NaN         NaN
# 4237375           NaN       NaN           NaN          NaN         NaN
#
#         is_nonsense is_unknown is_silent is_other_protein_variant   p_lp  \
# 4             False      False     False                    False  False
# 5             False      False     False                    False  False
# 6              True      False     False                    False  False
# 7              True      False     False                    False  False
# 8             False      False     False                    False  False
# ...             ...        ...       ...                      ...    ...
# 4236947         NaN        NaN       NaN                      NaN    NaN
# 4236994         NaN        NaN       NaN                      NaN    NaN
# 4236995         NaN        NaN       NaN                      NaN    NaN
# 4237374         NaN        NaN       NaN                      NaN    NaN
# 4237375         NaN        NaN       NaN                      NaN    NaN
#
#           b_lb    vus conflicting  \
# 4        False   True       False
# 5        False   True       False
# 6        False  False       False
# 7        False  False       False
# 8        False  False       False
# ...        ...    ...         ...
# 4236947    NaN    NaN         NaN
# 4236994    NaN    NaN         NaN
# 4236995    NaN    NaN         NaN
# 4237374    NaN    NaN         NaN
# 4237375    NaN    NaN         NaN
#
#                                             Name_name Name_transcript  \
# 4        NM_017547.4(FOXRED1):c.1289A>G (p.Asn430Ser)     NM_017547.4
# 5        NM_017547.4(FOXRED1):c.1289A>G (p.Asn430Ser)     NM_017547.4
# 6            NM_025152.3(NUBPL):c.166G>A (p.Gly56Arg)     NM_025152.3
# 7            NM_025152.3(NUBPL):c.166G>A (p.Gly56Arg)     NM_025152.3
# 8             NM_000410.4(HFE):c.845G>A (p.Cys282Tyr)     NM_000410.4
# ...                                               ...             ...
# 4236947     NM_133433.4(NIPBL):c.874A>G (p.Arg292Gly)     NM_133433.4
# 4236994    NM_005359.6(SMAD4):c.1259G>T (p.Arg420Leu)     NM_005359.6
# 4236995    NM_005359.6(SMAD4):c.1259G>T (p.Arg420Leu)     NM_005359.6
# 4237374    NM_001082971.2(DDC):c.782G>T (p.Cys261Phe)  NM_001082971.2
# 4237375    NM_001082971.2(DDC):c.782G>T (p.Cys261Phe)  NM_001082971.2
#
#         Name_geneSymbol Name_dnaVariant Name_proteinVariant CHROM  \
# 4               FOXRED1       c.1289A>G         p.Asn430Ser    15
# 5               FOXRED1       c.1289A>G         p.Asn430Ser    15
# 6                 NUBPL        c.166G>A          p.Gly56Arg    11
# 7                 NUBPL        c.166G>A          p.Gly56Arg    11
# 8                   HFE        c.845G>A         p.Cys282Tyr    11
# ...                 ...             ...                 ...   ...
# 4236947           NIPBL        c.874A>G         p.Arg292Gly   nan
# 4236994           SMAD4       c.1259G>T         p.Arg420Leu   nan
# 4236995           SMAD4       c.1259G>T         p.Arg420Leu   nan
# 4237374             DDC        c.782G>T         p.Cys261Phe   nan
# 4237375             DDC        c.782G>T         p.Cys261Phe   nan
#
#                  POS  REF  ALT      hgvs_pro
# 4         85342440.0    G    A  p.Gly1046Arg
# 5         84799209.0    G    A  p.Gly1046Arg
# 6        126145284.0    C    T   p.Gln232Ter
# 7        126275389.0    C    T   p.Gln232Ter
# 8        126147412.0    A    G   p.Asn430Ser
# ...              ...  ...  ...           ...
# 4236947          nan  nan  nan           NaN
# 4236994          nan  nan  nan           NaN
# 4236995          nan  nan  nan           NaN
# 4237374          nan  nan  nan           NaN
# 4237375          nan  nan  nan           NaN
#
# [5548820 rows x 63 columns]

# %%
out[0][out[0].Name.isna()]
# Out:
#          #AlleleID Type Name GeneID GeneSymbol HGNC_ID ClinicalSignificance  \
# 0              NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 1              NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 2              NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 3              NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 22             NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# ...            ...  ...  ...    ...        ...     ...                  ...
# 4236947        NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 4236994        NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 4236995        NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 4237374        NaN  NaN  NaN    NaN        NaN     NaN                  NaN
# 4237375        NaN  NaN  NaN    NaN        NaN     NaN                  NaN
#
#          ClinSigSimple LastEvaluated  RS# (dbSNP) nsv/esv (dbVar)  \
# 0                  NaN           NaN          NaN             NaN
# 1                  NaN           NaN          NaN             NaN
# 2                  NaN           NaN          NaN             NaN
# 3                  NaN           NaN          NaN             NaN
# 22                 NaN           NaN          NaN             NaN
# ...                ...           ...          ...             ...
# 4236947            NaN           NaN          NaN             NaN
# 4236994            NaN           NaN          NaN             NaN
# 4236995            NaN           NaN          NaN             NaN
# 4237374            NaN           NaN          NaN             NaN
# 4237375            NaN           NaN          NaN             NaN
#
#         RCVaccession PhenotypeIDS PhenotypeList Origin OriginSimple Assembly  \
# 0                NaN          NaN           NaN    NaN          NaN      NaN
# 1                NaN          NaN           NaN    NaN          NaN      NaN
# 2                NaN          NaN           NaN    NaN          NaN      NaN
# 3                NaN          NaN           NaN    NaN          NaN      NaN
# 22               NaN          NaN           NaN    NaN          NaN      NaN
# ...              ...          ...           ...    ...          ...      ...
# 4236947          NaN          NaN           NaN    NaN          NaN      NaN
# 4236994          NaN          NaN           NaN    NaN          NaN      NaN
# 4236995          NaN          NaN           NaN    NaN          NaN      NaN
# 4237374          NaN          NaN           NaN    NaN          NaN      NaN
# 4237375          NaN          NaN           NaN    NaN          NaN      NaN
#
#         ChromosomeAccession Chromosome  Start  Stop ReferenceAllele  \
# 0                       NaN        NaN    NaN   NaN             NaN
# 1                       NaN        NaN    NaN   NaN             NaN
# 2                       NaN        NaN    NaN   NaN             NaN
# 3                       NaN        NaN    NaN   NaN             NaN
# 22                      NaN        NaN    NaN   NaN             NaN
# ...                     ...        ...    ...   ...             ...
# 4236947                 NaN        NaN    NaN   NaN             NaN
# 4236994                 NaN        NaN    NaN   NaN             NaN
# 4236995                 NaN        NaN    NaN   NaN             NaN
# 4237374                 NaN        NaN    NaN   NaN             NaN
# 4237375                 NaN        NaN    NaN   NaN             NaN
#
#         AlternateAllele Cytogenetic ReviewStatus  NumberSubmitters Guidelines  \
# 0                   NaN         NaN          NaN               NaN        NaN
# 1                   NaN         NaN          NaN               NaN        NaN
# 2                   NaN         NaN          NaN               NaN        NaN
# 3                   NaN         NaN          NaN               NaN        NaN
# 22                  NaN         NaN          NaN               NaN        NaN
# ...                 ...         ...          ...               ...        ...
# 4236947             NaN         NaN          NaN               NaN        NaN
# 4236994             NaN         NaN          NaN               NaN        NaN
# 4236995             NaN         NaN          NaN               NaN        NaN
# 4237374             NaN         NaN          NaN               NaN        NaN
# 4237375             NaN         NaN          NaN               NaN        NaN
#
#         TestedInGTR OtherIDs  SubmitterCategories  VariationID  PositionVCF  \
# 0               NaN      NaN                  NaN          NaN          NaN
# 1               NaN      NaN                  NaN          NaN          NaN
# 2               NaN      NaN                  NaN          NaN          NaN
# 3               NaN      NaN                  NaN          NaN          NaN
# 22              NaN      NaN                  NaN          NaN          NaN
# ...             ...      ...                  ...          ...          ...
# 4236947         NaN      NaN                  NaN          NaN          NaN
# 4236994         NaN      NaN                  NaN          NaN          NaN
# 4236995         NaN      NaN                  NaN          NaN          NaN
# 4237374         NaN      NaN                  NaN          NaN          NaN
# 4237375         NaN      NaN                  NaN          NaN          NaN
#
#         ReferenceAlleleVCF AlternateAlleleVCF SomaticClinicalImpact  \
# 0                      NaN                NaN                   NaN
# 1                      NaN                NaN                   NaN
# 2                      NaN                NaN                   NaN
# 3                      NaN                NaN                   NaN
# 22                     NaN                NaN                   NaN
# ...                    ...                ...                   ...
# 4236947                NaN                NaN                   NaN
# 4236994                NaN                NaN                   NaN
# 4236995                NaN                NaN                   NaN
# 4237374                NaN                NaN                   NaN
# 4237375                NaN                NaN                   NaN
#
#         SomaticClinicalImpactLastEvaluated ReviewStatusClinicalImpact  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 22                                     NaN                        NaN
# ...                                    ...                        ...
# 4236947                                NaN                        NaN
# 4236994                                NaN                        NaN
# 4236995                                NaN                        NaN
# 4237374                                NaN                        NaN
# 4237375                                NaN                        NaN
#
#         Oncogenicity OncogenicityLastEvaluated ReviewStatusOncogenicity  \
# 0                NaN                       NaN                      NaN
# 1                NaN                       NaN                      NaN
# 2                NaN                       NaN                      NaN
# 3                NaN                       NaN                      NaN
# 22               NaN                       NaN                      NaN
# ...              ...                       ...                      ...
# 4236947          NaN                       NaN                      NaN
# 4236994          NaN                       NaN                      NaN
# 4236995          NaN                       NaN                      NaN
# 4237374          NaN                       NaN                      NaN
# 4237375          NaN                       NaN                      NaN
#
#         is_pathogenic is_benign HGVSp RefSeq_nuc is_missense is_nonsense  \
# 0                 NaN       NaN   NaN        NaN         NaN         NaN
# 1                 NaN       NaN   NaN        NaN         NaN         NaN
# 2                 NaN       NaN   NaN        NaN         NaN         NaN
# 3                 NaN       NaN   NaN        NaN         NaN         NaN
# 22                NaN       NaN   NaN        NaN         NaN         NaN
# ...               ...       ...   ...        ...         ...         ...
# 4236947           NaN       NaN   NaN        NaN         NaN         NaN
# 4236994           NaN       NaN   NaN        NaN         NaN         NaN
# 4236995           NaN       NaN   NaN        NaN         NaN         NaN
# 4237374           NaN       NaN   NaN        NaN         NaN         NaN
# 4237375           NaN       NaN   NaN        NaN         NaN         NaN
#
#         is_unknown is_silent is_other_protein_variant p_lp b_lb  vus  \
# 0              NaN       NaN                      NaN  NaN  NaN  NaN
# 1              NaN       NaN                      NaN  NaN  NaN  NaN
# 2              NaN       NaN                      NaN  NaN  NaN  NaN
# 3              NaN       NaN                      NaN  NaN  NaN  NaN
# 22             NaN       NaN                      NaN  NaN  NaN  NaN
# ...            ...       ...                      ...  ...  ...  ...
# 4236947        NaN       NaN                      NaN  NaN  NaN  NaN
# 4236994        NaN       NaN                      NaN  NaN  NaN  NaN
# 4236995        NaN       NaN                      NaN  NaN  NaN  NaN
# 4237374        NaN       NaN                      NaN  NaN  NaN  NaN
# 4237375        NaN       NaN                      NaN  NaN  NaN  NaN
#
#         conflicting                                     Name_name  \
# 0               NaN  NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)
# 1               NaN  NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)
# 2               NaN   NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)
# 3               NaN   NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)
# 22              NaN       NM_000410.4(HFE):c.381A>C (p.Gln127His)
# ...             ...                                           ...
# 4236947         NaN     NM_133433.4(NIPBL):c.874A>G (p.Arg292Gly)
# 4236994         NaN    NM_005359.6(SMAD4):c.1259G>T (p.Arg420Leu)
# 4236995         NaN    NM_005359.6(SMAD4):c.1259G>T (p.Arg420Leu)
# 4237374         NaN    NM_001082971.2(DDC):c.782G>T (p.Cys261Phe)
# 4237375         NaN    NM_001082971.2(DDC):c.782G>T (p.Cys261Phe)
#
#         Name_transcript Name_geneSymbol Name_dnaVariant Name_proteinVariant  \
# 0           NM_014630.3          ZNF592       c.3136G>A        p.Gly1046Arg
# 1           NM_014630.3          ZNF592       c.3136G>A        p.Gly1046Arg
# 2           NM_017547.4         FOXRED1        c.694C>T         p.Gln232Ter
# 3           NM_017547.4         FOXRED1        c.694C>T         p.Gln232Ter
# 22          NM_000410.4             HFE        c.381A>C         p.Gln127His
# ...                 ...             ...             ...                 ...
# 4236947     NM_133433.4           NIPBL        c.874A>G         p.Arg292Gly
# 4236994     NM_005359.6           SMAD4       c.1259G>T         p.Arg420Leu
# 4236995     NM_005359.6           SMAD4       c.1259G>T         p.Arg420Leu
# 4237374  NM_001082971.2             DDC        c.782G>T         p.Cys261Phe
# 4237375  NM_001082971.2             DDC        c.782G>T         p.Cys261Phe
#
#         CHROM  POS  REF  ALT hgvs_pro
# 0         nan  nan  nan  nan      NaN
# 1         nan  nan  nan  nan      NaN
# 2         nan  nan  nan  nan      NaN
# 3         nan  nan  nan  nan      NaN
# 22        nan  nan  nan  nan      NaN
# ...       ...  ...  ...  ...      ...
# 4236947   nan  nan  nan  nan      NaN
# 4236994   nan  nan  nan  nan      NaN
# 4236995   nan  nan  nan  nan      NaN
# 4237374   nan  nan  nan  nan      NaN
# 4237375   nan  nan  nan  nan      NaN
#
# [1311440 rows x 63 columns]

# %%
pd.DataFrame.from_records(out.values)

# %%
clinvar.loc[clinvar.RefSeq_nuc != clinvar.Name_transcript, ["Name",'RefSeq_nuc','Name_transcript']]

# %%
parse_clinvar_name("NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)")

# %%
clinvar.shape

# %%
paresed_names

# %%
clinvar.iloc[0]

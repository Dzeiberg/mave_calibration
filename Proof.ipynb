# %% [markdown]
# To prove that $ \frac{P(x)}{B(x)} $ is monotonic under the assumptions given, we will start with the definitions of $ P(x) $ and $ B(x) $ and proceed step by step.
#
# ### Definitions:
# We are given the following:
#
# $$
# P(x) = a f(x) + (1 - a) g(x)
# $$
# $$
# B(x) = c f(x) + (1 - c) g(x)
# $$
# with $ a > c $ and the assumption that the ratio $ \frac{f(x)}{g(x)} $ is monotonic (either increasing or decreasing).
#
# We aim to show that $ \frac{P(x)}{B(x)} $ is also monotonic. Let's proceed by computing the derivative of this ratio and analyzing its sign.
#
# ### Step 1: Express $ \frac{P(x)}{B(x)} $
#
# $$
# \frac{P(x)}{B(x)} = \frac{a f(x) + (1 - a) g(x)}{c f(x) + (1 - c) g(x)}
# $$
#
# ### Step 2: Differentiate $ \frac{P(x)}{B(x)} $ with respect to $ x $
#
# Using the quotient rule, the derivative of $ \frac{P(x)}{B(x)} $ is:
#
# $$
# \frac{d}{dx} \left( \frac{P(x)}{B(x)} \right) = \frac{ \left( a f'(x) + (1 - a) g'(x) \right) \cdot \left( c f(x) + (1 - c) g(x) \right) - \left( c f'(x) + (1 - c) g'(x) \right) \cdot \left( a f(x) + (1 - a) g(x) \right) }{\left( c f(x) + (1 - c) g(x) \right)^2}
# $$
#
# To simplify the analysis, let’s break down the terms in the numerator.
#
# ### Step 3: Simplify the numerator
#
# The numerator is:
#
# $$
# N(x) = \left( a f'(x) + (1 - a) g'(x) \right) \left( c f(x) + (1 - c) g(x) \right) - \left( c f'(x) + (1 - c) g'(x) \right) \left( a f(x) + (1 - a) g(x) \right)
# $$
#
# Expanding both terms:
#
# $$
# N(x) = a c f'(x) f(x) + a (1 - c) f'(x) g(x) + (1 - a) c g'(x) f(x) + (1 - a)(1 - c) g'(x) g(x)
# $$
# $$
# - \left( c a f'(x) f(x) + c (1 - a) f'(x) g(x) + (1 - c) a g'(x) f(x) + (1 - c)(1 - a) g'(x) g(x) \right)
# $$
#
# Simplifying this:
#
# $$
# N(x) = a (1 - c) f'(x) g(x) + (1 - a) c g'(x) f(x) - c (1 - a) f'(x) g(x) - (1 - c) a g'(x) f(x)
# $$
#
# $$
# N(x) = (a - c) \left( f'(x) g(x) - g'(x) f(x) \right)
# $$
#
# ### Step 4: Analyze the sign of $ N(x) $
#
# The expression for the numerator simplifies to:
#
# $$
# N(x) = (a - c) \left( f'(x) g(x) - g'(x) f(x) \right)
# $$
#
# Since $ a > c $, the sign of $ N(x) $ depends on the sign of $ f'(x) g(x) - g'(x) f(x) $.
#
# - If $ \frac{f(x)}{g(x)} $ is monotonic, then $ f'(x) g(x) - g'(x) f(x) $ has a consistent sign (either always positive or always negative), because this is the condition for the derivative of a ratio to maintain monotonicity.
#
# Thus, the sign of $ N(x) $ is determined by the sign of $ f'(x) g(x) - g'(x) f(x) $, which is consistent due to the monotonicity of $ \frac{f(x)}{g(x)} $, and multiplied by the positive factor $ (a - c) $.
#
# ### Step 5: Conclusion
#
# Since the numerator $ N(x) $ has a consistent sign and the denominator $ \left( c f(x) + (1 - c) g(x) \right)^2 $ is always positive (assuming $ f(x) $ and $ g(x) $ are well-behaved functions), the sign of $ \frac{d}{dx} \left( \frac{P(x)}{B(x)} \right) $ is constant.
#
# Therefore, $ \frac{P(x)}{B(x)} $ is monotonic.
